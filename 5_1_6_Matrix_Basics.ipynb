# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita1013/Machine-Learning-with-Python/blob/master/5_1_6_Matrix_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scalar -> It ia just a single value
# eg. 24
#
# Vector=> It is a list of values either one row or one column
#
# eg. [2 -8 7] (row)
#
# Matrix => This cotains list of multiple rows and columns
#
# [1 4 5 ]
#
# [2 7 3 ]
#
# [8 -3 1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Role of Matrix in Machine Learning **
#
# -All the datasets we use represents some form of matrix (eg. 4 x 14 Matrix) 4-Rows and 14 columns
