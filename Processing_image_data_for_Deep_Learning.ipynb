# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita1013/Machine-Learning-with-Python/blob/master/Processing_image_data_for_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Topics:**
# 1. Reading an image file and converting it to a numpy array
# 2. Resizing an image
# 3. RGB to Grayscale conversion

# %%
# getting an image using web get
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3bbMc6MZBCw1ZaTyj4y9JzxS8P8ux_ZX93Q&s'
# Out:
# --2025-12-10 08:22:44--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3bbMc6MZBCw1ZaTyj4y9JzxS8P8ux_ZX93Q&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 173.194.206.113, 173.194.206.102, 173.194.206.100, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|173.194.206.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10350 (10K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcS3bbMc6MZBCw1ZaTyj4y9JzxS8P8ux_ZX93Q&s.1’
#
# images?q=tbn:ANd9Gc 100%[===================>]  10.11K  --.-KB/s    in 0s
#
# 2025-12-10 08:22:44 (48.7 MB/s) - ‘images?q=tbn:ANd9GcS3bbMc6MZBCw1ZaTyj4y9JzxS8P8ux_ZX93Q&s.1’ saved [10350/10350]

# %% [markdown]
# **Libraries that can be used for image processing :**
# 1. matplotlib.image
# 2. pillow
# 3. OpenCV(cv2)

# %%
# importing the image module Iron Matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (224, 225, 3)

# %%
print(img)
# Out:
# [[[167 189 124]
#   [167 189 124]
#   [167 189 124]
#   ...
#   [163 184 117]
#   [163 184 117]
#   [163 184 117]]
#
#  [[167 189 124]
#   [167 189 124]
#   [167 189 124]
#   ...
#   [163 184 117]
#   [163 184 117]
#   [163 184 117]]
#
#  [[168 190 125]
#   [168 190 125]
#   [168 190 125]
#   ...
#   [162 183 116]
#   [162 183 116]
#   [162 183 116]]
#
#  ...
#
#  [[107 127  68]
#   [106 126  65]
#   [106 124  66]
#   ...
#   [124 123  69]
#   [121 115  63]
#   [121 109  59]]
#
#  [[105 124  68]
#   [105 125  66]
#   [106 123  68]
#   ...
#   [118 131  75]
#   [116 125  70]
#   [119 122  69]]
#
#  [[105 124  68]
#   [105 124  68]
#   [106 123  68]
#   ...
#   [117 137  78]
#   [115 133  75]
#   [120 129  74]]]

# %%
img_2 = mpimg.imread('/content/dog-grayscale.jpg')

# %%
print(img_2.shape)
# Out:
# (168, 300, 3)

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using pillow

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized  = img.resize((150,150))

# %%
img_resized.save('dog image resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/dog image resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (150, 150, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing openCV library

import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (224, 225, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (224, 225)

# %% [markdown]
# cv2.imshow() will display the image but this will not be allowed in google colab
#
# **Alternative**
#
# from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=225x224>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_img.jpg', grayscale_image)
# Out:
# True
