# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita1013/Machine-Learning-with-Python/blob/master/5_1_5_Vector_Operations_Dot_product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Dot Products of 2 Vectors

# %%
# vectors=> a & b
a = np.array([2,3])

b = np.array([4,4])

a_dot_b = np.dot(a,b)

print(a_dot_b)
# Out:
# 20

# %%
c = np.array([40,20,35])

d = np.array([53,24,68])

c_dot_d = np.dot(c,d)

print(c_dot_d)
# Out:
# 4980

# %% [markdown]
# Cross Product of 2 vectors

# %%
# vectors=> a & b
a = np.array([2,3])

b = np.array([4,4])

a_cross_b = np.cross(a,b)

print(a_cross_b)
# Out:
# -4
# /tmp/ipython-input-3090766447.py:6: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   a_cross_b = np.cross(a,b)

# %%
# 3D vector
m = np.array([5,10,20])

n = np.array([18,32,50])

m_cross_n = np.cross(m,n)

print(m_cross_n)
# Out:
# [-140  110  -20]

# %% [markdown]
# Projection of "a" vector on "v" vector

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = np.array([2,5])

v = np.array([8,-6])

# magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v

print("Projection of a vector on v vector = ", proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [-1.12  0.84]

# %%
a = np.array([23,45,62])
v = np.array([45,82,67])

# magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v
print('Projection of a vector on a v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on a v vector =  [30.18242937 54.99909352 44.93828373]
