# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita1013/Machine-Learning-with-Python/blob/master/Pandas_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library:
#
# Useful for Data Processing & Analysis

# %% [markdown]
# Pandas Data Frame:
#
# Pandas Data-frame is two diemnsional tabular data structure with labeled axes (rows & columns)

# %%
# importing the pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# California Housing

# %%
#importing california dataset
from sklearn.datasets import fetch_california_housing

# %%
california_dataset = fetch_california_housing()

# %%
type(california_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(california_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
california_df = pd.DataFrame(california_dataset.data, columns = california_dataset.feature_names)

# %%
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
california_df.shape
# Out:
# (20640, 8)

# %% [markdown]
# Importing the data from a CSV files to a pandas DataFrame

# %%
# csv file to pandas DataFrame (df)
diabetes_df = pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the Data from Excel File to pandas dataframe:
#
#
# pd.read_excel("file_path")

# %% [markdown]
# Exporting a datafreame to csv file

# %%
california_df.to_csv('california.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-3692711104.py in <cell line: 0>()
# ----> 1 california_df.to_csv('california.csv')
#
# NameError: name 'california_df' is not defined

# %% [markdown]
# Exporting the pandas dataframe to a Excel file:
#
# df.to_excel("file_name")

# %%
#creating a dataframe with random values
random_df = pd.DataFrame(np.random.rand(20, 10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.640130  0.415632  0.313509  0.012526  0.675216  0.045185  0.124704
# 1  0.386218  0.584389  0.962193  0.960750  0.273402  0.110089  0.164067
# 2  0.236339  0.436894  0.412441  0.868515  0.053103  0.043181  0.722907
# 3  0.561184  0.774847  0.731266  0.979403  0.500949  0.129441  0.874151
# 4  0.247720  0.755421  0.589641  0.267665  0.992870  0.634224  0.080226
#
#           7         8         9
# 0  0.355570  0.548737  0.697916
# 1  0.128193  0.097505  0.421737
# 2  0.200368  0.105223  0.304862
# 3  0.758607  0.914661  0.175517
# 4  0.982039  0.758028  0.708283

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a DataFrame

# %%
# Finding no of Rows & Columns
california_df.shape
# Out:
# (20640, 8)

# %%
# First 5 rows in a DataFrame
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Last 5 Rows in a dataframe
california_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
# information about the dataframe
california_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
# finding the number of missing values in  a dataframe
california_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
# diabetes dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Counting the  values based on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# Group the values based on the mean
diabetes_df.groupby('Outcome').mean()  # average values for all
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
# count or numbers of values
california_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
california_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# standard Deviation --> cloumns wise
california_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
# Finding min value
california_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
# Finding maximum
california_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
# all the statistical) measures about the dataframes
california_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# Manipulating a Dataframe

# %%
# Adding a columns toa dataframe
california_df["Price"] = california_dataset.target

# %%
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# removin a row
california_df.drop(index=0, axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# Drop a Column
california_df.drop(columns='HouseAge', axis=1)
# Out:
#        MedInc  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude
# 0      8.3252  6.984127   1.023810       322.0  2.555556     37.88    -122.23
# 1      8.3014  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2      7.2574  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3      5.6431  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4      3.8462  6.281853   1.081081       565.0  2.181467     37.85    -122.25
# ...       ...       ...        ...         ...       ...       ...        ...
# 20635  1.5603  5.045455   1.133333       845.0  2.560606     39.48    -121.09
# 20636  2.5568  6.114035   1.315789       356.0  3.122807     39.49    -121.21
# 20637  1.7000  5.205543   1.120092      1007.0  2.325635     39.43    -121.22
# 20638  1.8672  5.329513   1.171920       741.0  2.123209     39.43    -121.32
# 20639  2.3886  5.254717   1.162264      1387.0  2.616981     39.37    -121.24
#
# [20640 rows x 7 columns]

# %%
# locating a row using the index value
california_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Name: 2, dtype: float64

# %%
#  locating a particular column
print(california_df.iloc[:0])   # prints the first column
print(california_df.iloc[:1])   # prints the second column
print(california_df.iloc[:2])   # prints the third column
print(california_df.iloc[:-1])  # prints the last column
# Out:
# Empty DataFrame
# Columns: [MedInc, HouseAge, AveRooms, AveBedrms, Population, AveOccup, Latitude, Longitude]
# Index: []
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
#
#    Longitude
# 0    -122.23
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#    Longitude
# 0    -122.23
# 1    -122.22
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# ...

# %% [markdown]
# Correlation:
#
# 1. Positive Correlation
# 2. Negative Correlation

# %%
california_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#
#             Latitude  Longitude
# MedInc     -0.079809  -0.015176
# HouseAge    0.011173  -0.108197
# AveRooms    0.106389  -0.027540
# AveBedrms   0.069721   0.013344
# Population -0.108785   0.099773
# AveOccup    0.002366   0.002476
# Latitude    1.000000  -0.924664
# Longitude  -0.924664   1.000000
