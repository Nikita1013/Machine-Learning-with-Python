# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita1013/Machine-Learning-with-Python/blob/master/K_Nearest_Neighbors(KNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Claculating the Euclidean and Manhattan Distance in Python

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np

# %% [markdown]
# Euclidean Distance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# consider two points with 2 Dimensions
p1 = (1,1)
p2 = (2,2)

# %%
# calculating the Euclidean Distance

dist = (p1[0] - p2[0])**2  + (p1[1] - p2[1])**2

euclidean_dist = np.sqrt(dist)
print(euclidean_dist)
# Out:
# 1.4142135623730951

# %%
# consider two points with 3 Dimensions
p1 = (1,1,1)
p2 = (2,2,2)

dist = (p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2

euclidean_dist = np.sqrt(dist)
print(euclidean_dist)
# Out:
# 1.7320508075688772

# %%
# consider two points with 4 dimensions
p1 = (1,1,1,1)
p2 = (2,2,2,2)

dist = 0

for i in range(len(p1)):
  dist = dist + (p1[i] - p2[i])**2

euclidean_dist = np.sqrt(dist)
print(euclidean_dist)
# Out:
# 2.0

# %% [markdown]
# Creating a Function for calculating Euclidean Distance

# %%
def get_euclidean_distance(p1,p2):

  dist = 0

  for i in range(len(p1)):
    dist = dist + (p1[i] - p2[i])**2

  euclidean_dist = np.sqrt(dist)
  print(euclidean_dist)

# %%
get_euclidean_distance((1,1,1),(2,2,2))
# Out:
# 1.7320508075688772

# %% [markdown]
# Manhattan Distance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Creating a Function for Manhattan Distance

# %%
def get_manhattan_distance(p1,p2):

  dist = 0

  for i in range(len(p1)):
    dist = dist + abs(p1[i] - p2[i])

  manhattan_dist = dist
  print(manhattan_dist)

# %%
get_manhattan_distance((1,1,1,1),(2,2,2,2))
# Out:
# 4

# %%
# abs -- absolute value
print(abs(1-2))
# Out:
# 1

# %% [markdown]
# Creating distance between two datapoints

# %%
# distance between two similar data points

print(get_euclidean_distance((63,1,3,145,233,1,0,150,0,2.3,0,0,1),(37,1,2,130,250,0,1,187,0,3.5,0,0,2)))
print(get_manhattan_distance((63,1,3,145,233,1,0,150,0,2.3,0,0,1),(37,1,2,130,250,0,1,187,0,3.5,0,0,2)))
# Out:
# 50.640300157088326
# None
# 100.2
# None

# %%
# distance between two dissimilar data points

print(get_euclidean_distance((63,1,3,145,233,1,0,150,0,2.3,0,0,1),(66,0,3,150,226,0,1,114,0,2.6,0,0,2,1)))
print(get_manhattan_distance((63,1,3,145,233,1,0,150,0,2.3,0,0,1),(66,0,3,150,226,0,1,114,0,2.6,0,0,2,1)))
# Out:
# 37.189917988616216
# None
# 55.3
# None
