# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita1013/Machine-Learning-with-Python/blob/master/Dataset_sites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Collection Sites:
#
#
# 1.  Kaggle
# 2.  UCI Machine Learning Repository
# 3.  Google Dataset Search

# %%
import pandas as pd

# %%
# loading a dataset to a pandas dataframe
dataset = pd.read_csv('/content/housing.csv')

# %%
dataset.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0
